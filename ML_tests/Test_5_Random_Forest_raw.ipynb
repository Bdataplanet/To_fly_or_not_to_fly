# %% [markdown]
# # Retrieve Data from Database

# %% [markdown]
# In order to connect to the database, first, make sure:
# 1. …you have a local (running) database with the `hostname`, `database` name, `username`, and `port` number as specified in `/resources/config/gadb_pg_config.py`.
# 2. …the `airports` and `flights_and_weather` tables have data.
#
# If the `airports` and `flights_and_weather` tables do not have data, you must first run `/download_and_prepare_datasets/02_prepare_and_store_data.ipynb` to populate the database.

# %%
import os
import time

# %%
os.chdir(os.path.join('..','resources'))

# %% [markdown]
# ## Connect to Database

# %%
# Database configuration details
from config import gadb_pg_config as cfg

# To connect to SQL database
import sqlalchemy as db
# from sqlalchemy import create_engine, MetaData, Table, text, types

# To enter passwords without exposing them
from getpass import getpass

# %% [markdown]
# Most of the database information is already in `cfg` (above). However, you will have to enter your password below.

# %%
password = getpass('Enter database password')
# Out:
# Enter database password········

# %%
start_time = time.time()

# %%
db_string = f"postgresql+psycopg2://{cfg.username}:{password}@{cfg.hostname}:{cfg.port}/{cfg.database}"

# %%
engine = db.create_engine(
    future=True,
#     echo=True,
    url=db_string
)

# %% [markdown]
# ## Access Database Tables and Create Table Aliases

# %%
db_meta = db.MetaData()

# %%
# Access the `airports` and `flights_and_weather` tables and assign them to variables
airports_table = db.Table('airports', db_meta, autoload_with=engine)
faw_table = db.Table('flights_and_weather', db_meta, autoload_with=engine)
faw = faw_table.alias('faw')
orig = airports_table.alias('orig')
dest = airports_table.alias('dest')

# %% [markdown]
# ## Extract Full, Joined Dataset to Pandas Dataframe

# %%
from io import StringIO
import pandas as pd

# %%
# Function to extract from database query to Pandas dataframe
# Adapted from <https://towardsdatascience.com/optimizing-pandas-read-sql-for-postgres-f31cd7f707ab>
def read_sql_inmem(query, db_engine, **kwargs):
    copy_sql = "COPY ({query}) TO STDOUT WITH CSV {head}".format(
       query=query, head="HEADER"
    )
    conn = db_engine.raw_connection()
    cur = conn.cursor()
    store = StringIO()
    cur.copy_expert(copy_sql, store)
    store.seek(0)
    df = pd.read_csv(store, **kwargs)
    return df

# %%
# The query composed as an SQLAlchemy table object
get_all = (
    db.select([
        faw,
        orig.c.lat_decimal.label('origin_lat'),
        orig.c.lon_decimal.label('origin_lon'),
        dest.c.lat_decimal.label('destination_lat'),
        dest.c.lon_decimal.label('destination_lon')
    ])
    .select_from(
        faw
        .join(orig, orig.c.iata_code == faw.c.origin_airport, isouter=True)
        .join(dest, dest.c.iata_code == faw.c.destination_airport, isouter=True)
    )
    .order_by(faw.c.id)
)

# %%
def print_shape(df):
    df_rows, df_cols = df.shape
    print(f"{df_rows:,} rows × {df_cols:,} columns")

# %%
def df_details(df):
    return pd.concat(
        [
            df.dtypes,
            df.isna().sum(),
            pd.Series(
                data=[df[col].dropna().is_unique for col in df.columns],
                index=df.columns
            )
        ],
        axis=1,
        keys=['data_type','null_count','unique']
    )

# %%
# Run the query, and save the result to a dataframe
combined_df = read_sql_inmem(
    query=get_all,
#     query=get_all.limit(10).compile(engine, compile_kwargs={"literal_binds": True}),
    db_engine=engine,
    index_col='id',
    converters={'cancelled':(lambda x: True if x == 't' else False)}
)
# .sort_index(kind='mergesort')

print_shape(combined_df)
# Out:
# 5,468,069 rows × 35 columns

# %%
# "Full-width display" function to display all columns of a dataframe
def fw_disp(df):
    with pd.option_context('display.max_columns',None):
        display(df)

# %%
fw_disp(combined_df.head())
# Out:
#    carrier_code  flight_number origin_airport destination_airport flight_date  \
# id
# 0            AS            121            SEA                 ANC  2019-07-01
# 1            B6           1092            BQN                 FLL  2019-07-01
# 2            B6            668            PSE                 MCO  2019-07-01
# 3            F9            402            LAX                 DEN  2019-07-01
# 4            F9            790            PDX                 DEN  2019-07-01
#
#     scheduled_elapsed_time tail_number  departure_delay  arrival_delay  \
# id
# 0                      215      N611AS                0            -16
# 1                      155      N589JB              -19            -40
# 2                      175      N662JB               73             69
# 3                      143      N706FR               -1             -7
# 4                      156      N350FR               21             10
#
#     delay_carrier  delay_weather  delay_national_aviation_system  \
# id
# 0               0              0                               0
# 1               0              0                               0
# 2               0              0                               0
# 3               0              0                               0
# 4               0              0                               0
#
#     delay_security  delay_late_aircarft_arrival  cancelled  \
# id
# 0                0                            0      False
# 1                0                            0      False
# 2                0                           69      False
# 3                0                            0      False
# 4                0                            0      False
#
#    scheduled_departure_dt scheduled_arrival_dt  actual_departure_dt  \
# id
# 0     2019-07-01 00:40:00  2019-07-01 03:15:00  2019-07-01 00:40:00
# 1     2019-07-01 01:26:00  2019-07-01 04:01:00  2019-07-01 01:07:00
# 2     2019-07-01 01:15:00  2019-07-01 04:10:00  2019-07-01 02:28:00
# 3     2019-07-01 00:59:00  2019-07-01 04:22:00  2019-07-01 00:58:00
# 4     2019-07-01 00:55:00  2019-07-01 04:31:00  2019-07-01 01:16:00
#
#       actual_arrival_dt     station_x  hourlydrybulbtemperature_x  \
# id
# 0   2019-07-01 02:59:00  7.279302e+10                        65.0
# 1   2019-07-01 03:21:00  7.851401e+10                        79.0
# 2   2019-07-01 05:19:00           NaN                         NaN
# 3   2019-07-01 04:15:00  7.229502e+10                        65.0
# 4   2019-07-01 04:41:00  7.269802e+10                        66.0
#
#     hourlyprecipitation_x  hourlystationpressure_x  hourlyvisibility_x  \
# id
# 0                     0.0                    29.60                10.0
# 1                     NaN                    29.81                10.0
# 2                     NaN                      NaN                 NaN
# 3                     0.0                    29.60                10.0
# 4                     0.0                    29.92                10.0
#
#     hourlywindspeed_x     station_y  hourlydrybulbtemperature_y  \
# id
# 0                 6.0  7.027253e+10                        57.0
# 1                 9.0  7.478301e+10                        78.0
# 2                 NaN  7.220501e+10                        76.0
# 3                 6.0  7.256500e+10                        62.0
# 4                 6.0  7.256500e+10                        62.0
#
#     hourlyprecipitation_y  hourlystationpressure_y  hourlyvisibility_y  \
# id
# 0                     0.0                    30.04                10.0
# 1                     0.0                    30.01                10.0
# 2                     0.0                    29.93                10.0
# 3                     0.0                    24.69                10.0
# 4                     0.0                    24.70                 8.0
#
#     hourlywindspeed_y  origin_lat  origin_lon  destination_lat  \
# id
# 0                 3.0      47.449    -122.309           61.174
# 1                 0.0      18.495     -67.129           26.072
# 2                 3.0      18.008     -66.563           28.429
# 3                 8.0      33.942    -118.408           39.858
# 4                10.0      45.589    -122.597           39.858
#
#     destination_lon
# id
# 0          -149.996
# 1           -80.153
# 2           -81.316
# 3          -104.667
# 4          -104.667

# %%
df_details(combined_df)
# Out:
#                                data_type  null_count  unique
# carrier_code                      object           0   False
# flight_number                      int64           0   False
# origin_airport                    object           0   False
# destination_airport               object           0   False
# flight_date                       object           0   False
# scheduled_elapsed_time             int64           0   False
# tail_number                       object        6973   False
# departure_delay                    int64           0   False
# arrival_delay                      int64           0   False
# delay_carrier                      int64           0   False
# delay_weather                      int64           0   False
# delay_national_aviation_system     int64           0   False
# delay_security                     int64           0   False
# delay_late_aircarft_arrival        int64           0   False
# cancelled                           bool           0   False
# scheduled_departure_dt            object           0   False
# scheduled_arrival_dt              object           0   False
# actual_departure_dt               object       40065   False
# actual_arrival_dt                 object       43808   False
# station_x                        float64        2073   False
# hourlydrybulbtemperature_x       float64        2073   False
# hourlyprecipitation_x            float64        9881   False
# hourlystationpressure_x          float64        2073   False
# hourlyvisibility_x               float64        2073   False
# hourlywindspeed_x                float64        2073   False
# station_y                        float64        2078   False
# hourlydrybulbtemperature_y       float64        2078   False
# hourlyprecipitation_y            float64        9896   False
# hourlystationpressure_y          float64        2078   False
# hourlyvisibility_y               float64        2078   False
# hourlywindspeed_y                float64        2078   False
# origin_lat                       float64      382438   False
# origin_lon                       float64      382438   False
# destination_lat                  float64      382775   False
# destination_lon                  float64      382775   False

# %%
print(f'Elapsed time: {(time.time() - start_time):,.3f} seconds.')
# Out:
# Elapsed time: 1,918.245 seconds.

# %% [markdown]
# # Prepare Data for Machine Learning

# %%
combined_df[['carrier_code','tail_number']].nunique(dropna=True)
# Out:
# carrier_code      10
# tail_number     6111
# dtype: int64

# %%
# Read in the data
ddir = r"/Users/neesha/Desktop/dataexport"
ddir
pt = os.path.join(ddir,'combined.csv')
pt
df = pd.read_csv(pt)
df.head()
# Out:
#    id carrier_code  flight_number origin_airport destination_airport  \
# 0   0           AS            121            SEA                 ANC
# 1   1           B6           1092            BQN                 FLL
# 2   2           B6            668            PSE                 MCO
# 3   3           F9            402            LAX                 DEN
# 4   4           F9            790            PDX                 DEN
#
#   flight_date  scheduled_elapsed_time tail_number  departure_delay  \
# 0  2019-07-01                     215      N611AS                0
# 1  2019-07-01                     155      N589JB              -19
# 2  2019-07-01                     175      N662JB               73
# 3  2019-07-01                     143      N706FR               -1
# 4  2019-07-01                     156      N350FR               21
#
#    arrival_delay  ...     station_y  hourlydrybulbtemperature_y  \
# 0            -16  ...  7.027253e+10                        57.0
# 1            -40  ...  7.478301e+10                        78.0
# 2             69  ...  7.220501e+10                        76.0
# 3             -7  ...  7.256500e+10                        62.0
# 4             10  ...  7.256500e+10                        62.0
#
#    hourlyprecipitation_y  hourlystationpressure_y  hourlyvisibility_y  \
# 0                    0.0                    30.04                10.0
# 1                    0.0                    30.01                10.0
# 2                    0.0                    29.93                10.0
# 3                    0.0                    24.69                10.0
# 4                    0.0                    24.70                 8.0
#
#   hourlywindspeed_y origin_lat origin_lon destination_lat destination_lon
# 0               3.0     47.449   -122.309          61.174        -149.996
# 1               0.0     18.495    -67.129          26.072         -80.153
# 2               3.0     18.008    -66.563          28.429         -81.316
# 3               8.0     33.942   -118.408          39.858        -104.667
# 4              10.0     45.589   -122.597          39.858        -104.667
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['id', 'carrier_code', 'flight_number', 'origin_airport',
#        'destination_airport', 'flight_date', 'scheduled_elapsed_time',
#        'tail_number', 'departure_delay', 'arrival_delay', 'delay_carrier',
#        'delay_weather', 'delay_national_aviation_system', 'delay_security',
#        'delay_late_aircarft_arrival', 'cancelled', 'scheduled_departure_dt',
#        'scheduled_arrival_dt', 'actual_departure_dt', 'actual_arrival_dt',
#        'station_x', 'hourlydrybulbtemperature_x', 'hourlyprecipitation_x',
#        'hourlystationpressure_x', 'hourlyvisibility_x', 'hourlywindspeed_x',
#        'station_y', 'hourlydrybulbtemperature_y', 'hourlyprecipitation_y',
#        'hourlystationpressure_y', 'hourlyvisibility_y', 'hourlywindspeed_y',
#        'origin_lat', 'origin_lon', 'destination_lat', 'destination_lon'],
#       dtype='object')

# %%
df['cancelled'].value_counts()
# Out:
# f    5426150
# t      41919
# Name: cancelled, dtype: int64

# %%
# Select columns to drop
drop_cols = [
    'flight_number',
    'origin_airport',
    'destination_airport',
    'tail_number',
    'departure_delay',
    'arrival_delay',
    'delay_carrier',
    'delay_weather',
    'delay_national_aviation_system',
    'delay_security',
    'delay_late_aircarft_arrival',
    'actual_departure_dt',
    'actual_arrival_dt'
]

# %% [markdown]
# ### 1.) origin_airport
# ### 2.) destination_airport
# ### 3.) departure_delay
# ### 4.) arrival_delay
# ### 5.) 'cancelled'
# ### 6.) station_x
# ### 7.) hourlydrybulbtemperature_x
# ### 8.) hourlyprecipitation_x
# ### 9.) hourlystationpressure_x
# ### 10.) 'hourlyvisibility_x',
# ### 11.) 'hourlywindspeed_x',
# ### 12.) 'station_y',
# ### 13.) 'hourlydrybulbtemperature_y',
# ### 15.) 'hourlyprecipitation_y',
# ###   16.)  'hourlystationpressure_y',
# ### 17.) 'hourlyvisibility_y',
# ### 18.) 'hourlywindspeed_y',
# ### 19.) 'origin_lat',
# ### 20 .) 'origin_lon',
# ### 21.) 'destination_lat',
# ### 22.) 'destination_lon'

# %%
df = combined_df.drop(columns=drop_cols)

# %%
fw_disp(df.head())
# Out:
#    carrier_code flight_date  scheduled_elapsed_time  cancelled  \
# id
# 0            AS  2019-07-01                     215      False
# 1            B6  2019-07-01                     155      False
# 2            B6  2019-07-01                     175      False
# 3            F9  2019-07-01                     143      False
# 4            F9  2019-07-01                     156      False
#
#    scheduled_departure_dt scheduled_arrival_dt     station_x  \
# id
# 0     2019-07-01 00:40:00  2019-07-01 03:15:00  7.279302e+10
# 1     2019-07-01 01:26:00  2019-07-01 04:01:00  7.851401e+10
# 2     2019-07-01 01:15:00  2019-07-01 04:10:00           NaN
# 3     2019-07-01 00:59:00  2019-07-01 04:22:00  7.229502e+10
# 4     2019-07-01 00:55:00  2019-07-01 04:31:00  7.269802e+10
#
#     hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 0                         65.0                    0.0
# 1                         79.0                    NaN
# 2                          NaN                    NaN
# 3                         65.0                    0.0
# 4                         66.0                    0.0
#
#     hourlystationpressure_x  hourlyvisibility_x  hourlywindspeed_x  \
# id
# 0                     29.60                10.0                6.0
# 1                     29.81                10.0                9.0
# 2                       NaN                 NaN                NaN
# 3                     29.60                10.0                6.0
# 4                     29.92                10.0                6.0
#
#        station_y  hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 0   7.027253e+10                        57.0                    0.0
# 1   7.478301e+10                        78.0                    0.0
# 2   7.220501e+10                        76.0                    0.0
# 3   7.256500e+10                        62.0                    0.0
# 4   7.256500e+10                        62.0                    0.0
#
#     hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 0                     30.04                10.0                3.0
# 1                     30.01                10.0                0.0
# 2                     29.93                10.0                3.0
# 3                     24.69                10.0                8.0
# 4                     24.70                 8.0               10.0
#
#     origin_lat  origin_lon  destination_lat  destination_lon
# id
# 0       47.449    -122.309           61.174         -149.996
# 1       18.495     -67.129           26.072          -80.153
# 2       18.008     -66.563           28.429          -81.316
# 3       33.942    -118.408           39.858         -104.667
# 4       45.589    -122.597           39.858         -104.667

# %%
# Date and time columns to be converted
dt_cols = [
    'flight_date',
    'scheduled_departure_dt',
    'scheduled_arrival_dt'
]

# %%
df[dt_cols].head()
# Out:
#    flight_date scheduled_departure_dt scheduled_arrival_dt
# id
# 0   2019-07-01    2019-07-01 00:40:00  2019-07-01 03:15:00
# 1   2019-07-01    2019-07-01 01:26:00  2019-07-01 04:01:00
# 2   2019-07-01    2019-07-01 01:15:00  2019-07-01 04:10:00
# 3   2019-07-01    2019-07-01 00:59:00  2019-07-01 04:22:00
# 4   2019-07-01    2019-07-01 00:55:00  2019-07-01 04:31:00

# %%
from datetime import datetime
import numpy as np

# %%
# Convert the date and time columns to Unix timestamps (integers)
for col in dt_cols:
    df[col] = pd.to_datetime(df[col]).view(np.int64)

# %%
df[dt_cols].dtypes
# Out:
# flight_date               int64
# scheduled_departure_dt    int64
# scheduled_arrival_dt      int64
# dtype: object

# %%
fw_disp(df.head())
# Out:
#    carrier_code          flight_date  scheduled_elapsed_time  cancelled  \
# id
# 0            AS  1561939200000000000                     215      False
# 1            B6  1561939200000000000                     155      False
# 2            B6  1561939200000000000                     175      False
# 3            F9  1561939200000000000                     143      False
# 4            F9  1561939200000000000                     156      False
#
#     scheduled_departure_dt  scheduled_arrival_dt     station_x  \
# id
# 0      1561941600000000000   1561950900000000000  7.279302e+10
# 1      1561944360000000000   1561953660000000000  7.851401e+10
# 2      1561943700000000000   1561954200000000000           NaN
# 3      1561942740000000000   1561954920000000000  7.229502e+10
# 4      1561942500000000000   1561955460000000000  7.269802e+10
#
#     hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 0                         65.0                    0.0
# 1                         79.0                    NaN
# 2                          NaN                    NaN
# 3                         65.0                    0.0
# 4                         66.0                    0.0
#
#     hourlystationpressure_x  hourlyvisibility_x  hourlywindspeed_x  \
# id
# 0                     29.60                10.0                6.0
# 1                     29.81                10.0                9.0
# 2                       NaN                 NaN                NaN
# 3                     29.60                10.0                6.0
# 4                     29.92                10.0                6.0
#
#        station_y  hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 0   7.027253e+10                        57.0                    0.0
# 1   7.478301e+10                        78.0                    0.0
# 2   7.220501e+10                        76.0                    0.0
# 3   7.256500e+10                        62.0                    0.0
# 4   7.256500e+10                        62.0                    0.0
#
#     hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 0                     30.04                10.0                3.0
# 1                     30.01                10.0                0.0
# 2                     29.93                10.0                3.0
# 3                     24.69                10.0                8.0
# 4                     24.70                 8.0               10.0
#
#     origin_lat  origin_lon  destination_lat  destination_lon
# id
# 0       47.449    -122.309           61.174         -149.996
# 1       18.495     -67.129           26.072          -80.153
# 2       18.008     -66.563           28.429          -81.316
# 3       33.942    -118.408           39.858         -104.667
# 4       45.589    -122.597           39.858         -104.667

# %%
# Drop rows with `NULL` values
df.dropna(how='any',inplace=True)

print_shape(df)
# Out:
# 4,708,900 rows × 22 columns

# %%
# Verify that no `NULL` values remain
df_new = df.dropna().copy()

# %%
df_new.isnull().sum()
# Out:
# carrier_code                  0
# flight_date                   0
# scheduled_elapsed_time        0
# cancelled                     0
# scheduled_departure_dt        0
# scheduled_arrival_dt          0
# station_x                     0
# hourlydrybulbtemperature_x    0
# hourlyprecipitation_x         0
# hourlystationpressure_x       0
# hourlyvisibility_x            0
# hourlywindspeed_x             0
# station_y                     0
# hourlydrybulbtemperature_y    0
# hourlyprecipitation_y         0
# hourlystationpressure_y       0
# hourlyvisibility_y            0
# hourlywindspeed_y             0
# origin_lat                    0
# origin_lon                    0
# destination_lat               0
# destination_lon               0
# dtype: int64

# %%
df_new['cancelled'].value_counts()
# Out:
# False    4674943
# True       33957
# Name: cancelled, dtype: int64

# %% [markdown]
# # Test Random Forest

# %%
# Initial imports.
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Define the features set.
X = df_new.copy()
X = X.drop("cancelled", axis=1)
X.head()
# Out:
#    carrier_code          flight_date  scheduled_elapsed_time  \
# id
# 0            AS  1561939200000000000                     215
# 3            F9  1561939200000000000                     143
# 4            F9  1561939200000000000                     156
# 5            F9  1561939200000000000                     158
# 6            AS  1561939200000000000                     400
#
#     scheduled_departure_dt  scheduled_arrival_dt     station_x  \
# id
# 0      1561941600000000000   1561950900000000000  7.279302e+10
# 3      1561942740000000000   1561954920000000000  7.229502e+10
# 4      1561942500000000000   1561955460000000000  7.269802e+10
# 5      1561942500000000000   1561955580000000000  7.249402e+10
# 6      1561942500000000000   1561955700000000000  7.253009e+10
#
#     hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 0                         65.0                    0.0
# 3                         65.0                    0.0
# 4                         66.0                    0.0
# 5                         58.0                    0.0
# 6                         71.0                    0.0
#
#     hourlystationpressure_x  hourlyvisibility_x  ...     station_y  \
# id                                               ...
# 0                     29.60                10.0  ...  7.027253e+10
# 3                     29.60                10.0  ...  7.256500e+10
# 4                     29.92                10.0  ...  7.256500e+10
# 5                     30.03                10.0  ...  7.256500e+10
# 6                     29.24                10.0  ...  7.027253e+10
#
#     hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 0                         57.0                    0.0
# 3                         62.0                    0.0
# 4                         62.0                    0.0
# 5                         62.0                    0.0
# 6                         57.0                    0.0
#
#     hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 0                     30.04                10.0                3.0
# 3                     24.69                10.0                8.0
# 4                     24.70                 8.0               10.0
# 5                     24.70                 8.0               10.0
# 6                     30.06                10.0                0.0
#
#     origin_lat  origin_lon  destination_lat  destination_lon
# id
# 0       47.449    -122.309           61.174         -149.996
# 3       33.942    -118.408           39.858         -104.667
# 4       45.589    -122.597           39.858         -104.667
# 5       37.619    -122.375           39.858         -104.667
# 6       41.979     -87.904           61.174         -149.996
#
# [5 rows x 21 columns]

# %%
# Define the target set.
y = df_new["cancelled"]

# %%
# Use the train_test_split function to create training and testing subsets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y,  random_state=1, stratify=y, test_size=0.1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4238010, 21), (470890, 21), (4238010,), (470890,))

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler

# %%
Le = LabelEncoder()

# %%
y_train[:5]
# Out:
# id
# 4248935    False
# 2850481    False
# 2146498    False
# 1530087    False
# 3241252    False
# Name: cancelled, dtype: bool

# %%
y_test[:5]
# Out:
# id
# 3845853    False
# 3524639    False
# 3543535    False
# 1269636    False
# 1680588    False
# Name: cancelled, dtype: bool

# %%
y_train_cln = Le.fit_transform(y_train)

# %%
y_train_cln
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
Le.classes_
# Out:
# array([False,  True])

# %%
y_test_cln = Le.transform(y_test)

# %%
y_test_cln
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train.dtypes
# Out:
# carrier_code                   object
# flight_date                     int64
# scheduled_elapsed_time          int64
# scheduled_departure_dt          int64
# scheduled_arrival_dt            int64
# station_x                     float64
# hourlydrybulbtemperature_x    float64
# hourlyprecipitation_x         float64
# hourlystationpressure_x       float64
# hourlyvisibility_x            float64
# hourlywindspeed_x             float64
# station_y                     float64
# hourlydrybulbtemperature_y    float64
# hourlyprecipitation_y         float64
# hourlystationpressure_y       float64
# hourlyvisibility_y            float64
# hourlywindspeed_y             float64
# origin_lat                    float64
# origin_lon                    float64
# destination_lat               float64
# destination_lon               float64
# dtype: object

# %%
obj_col = X_train.dtypes[X.dtypes == 'object'].index.values
num_col = X_train.dtypes[X.dtypes != 'object'].index.values

# %%
len(obj_col), len(num_col)
# Out:
# (1, 20)

# %%
obj_col
# Out:
# array(['carrier_code'], dtype=object)

# %%
num_col
# Out:
# array(['flight_date', 'scheduled_elapsed_time', 'scheduled_departure_dt',
#        'scheduled_arrival_dt', 'station_x', 'hourlydrybulbtemperature_x',
#        'hourlyprecipitation_x', 'hourlystationpressure_x',
#        'hourlyvisibility_x', 'hourlywindspeed_x', 'station_y',
#        'hourlydrybulbtemperature_y', 'hourlyprecipitation_y',
#        'hourlystationpressure_y', 'hourlyvisibility_y',
#        'hourlywindspeed_y', 'origin_lat', 'origin_lon', 'destination_lat',
#        'destination_lon'], dtype=object)

# %%
X.shape
# Out:
# (4708900, 21)

# %%
clf = ColumnTransformer([
    ('ohe', OneHotEncoder(sparse=False, handle_unknown = 'ignore'), obj_col),
    ('ss', StandardScaler(), num_col)
], remainder='passthrough')

# %%
X_train
# Out:
#         carrier_code          flight_date  scheduled_elapsed_time  \
# id
# 4248935           NK  1575504000000000000                     285
# 2850481           AA  1567641600000000000                     162
# 2146498           F9  1572739200000000000                     229
# 1530087           UA  1570320000000000000                     151
# 3241252           DL  1569110400000000000                     107
# ...              ...                  ...                     ...
# 3606642           WN  1565222400000000000                     180
# 1320101           DL  1561507200000000000                     309
# 1960516           AA  1571961600000000000                      96
# 1442810           B6  1569974400000000000                     159
# 2577735           UA  1574380800000000000                     131
#
#          scheduled_departure_dt  scheduled_arrival_dt     station_x  \
# id
# 4248935     1575570300000000000   1575576600000000000  7.252401e+10
# 2850481     1567680900000000000   1567683420000000000  7.225900e+10
# 2146498     1572760860000000000   1572767400000000000  7.231401e+10
# 1530087     1570353240000000000   1570365900000000000  7.238909e+10
# 3241252     1569190800000000000   1569197220000000000  7.253709e+10
# ...                         ...                   ...           ...
# 3606642     1565291400000000000   1565298600000000000  7.478301e+10
# 1320101     1561582500000000000   1561611840000000000  9.119002e+10
# 1960516     1571995800000000000   1572001560000000000  7.240501e+10
# 1442810     1570013340000000000   1570022880000000000  7.220501e+10
# 2577735     1574409600000000000   1574421060000000000  7.256500e+10
#
#          hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 4248935                        34.0                   0.00
# 2850481                        92.0                   0.00
# 2146498                        32.0                   0.00
# 1530087                        70.0                   0.00
# 3241252                        78.0                   0.00
# ...                             ...                    ...
# 3606642                        78.0                   0.00
# 1320101                        81.0                   0.00
# 1960516                        58.0                   0.00
# 1442810                        89.0                   0.00
# 2577735                        28.0                   0.02
#
#          hourlystationpressure_x  hourlyvisibility_x  ...     station_y  \
# id                                                    ...
# 4248935                    29.24               10.00  ...  7.238602e+10
# 2850481                    29.48               10.00  ...  7.227802e+10
# 2146498                    29.40               10.00  ...  7.256500e+10
# 1530087                    29.72               10.00  ...  7.256500e+10
# 3241252                    29.14               10.00  ...  7.250701e+10
# ...                          ...                 ...  ...           ...
# 3606642                    29.99               10.00  ...  7.225801e+10
# 1320101                    29.86               10.00  ...  7.229502e+10
# 1960516                    30.23               10.00  ...  7.250901e+10
# 1442810                    29.87               10.00  ...  7.250379e+10
# 2577735                    24.59                0.25  ...  7.243401e+10
#
#          hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 4248935                        53.0                   0.00
# 2850481                       103.0                   0.00
# 2146498                        39.0                   0.00
# 1530087                        56.0                   0.00
# 3241252                        65.0                   0.00
# ...                             ...                    ...
# 3606642                        90.0                   0.00
# 1320101                        63.0                   0.00
# 1960516                        63.0                   0.00
# 1442810                        77.0                   0.18
# 2577735                        38.0                   0.00
#
#          hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 4248935                    27.91                10.0                6.0
# 2850481                    28.74                10.0                3.0
# 2146498                    24.55                10.0                6.0
# 1530087                    24.86                10.0                5.0
# 3241252                    29.91                10.0                3.0
# ...                          ...                 ...                ...
# 3606642                    29.35                10.0                8.0
# 1320101                    29.63                 9.0                0.0
# 1960516                    30.26                10.0                3.0
# 1442810                    29.34                 1.5                5.0
# 2577735                    29.44                10.0                9.0
#
#          origin_lat  origin_lon  destination_lat  destination_lon
# id
# 4248935      41.412     -81.850           36.080         -115.152
# 2850481      32.896     -97.037           33.434         -112.008
# 2146498      35.214     -80.943           39.858         -104.667
# 1530087      36.776    -119.718           39.858         -104.667
# 3241252      42.212     -83.353           41.724          -71.428
# ...             ...         ...              ...              ...
# 3606642      26.072     -80.153           32.847          -96.852
# 1320101      20.899    -156.431           33.942         -118.408
# 1960516      38.852     -77.037           42.364          -71.005
# 1442810      28.429     -81.316           41.067          -73.707
# 2577735      39.858    -104.667           38.748          -90.360
#
# [4238010 rows x 21 columns]

# %%
X_train_cln = clf.fit_transform(X_train)
X_test_cln = clf.transform(X_test)

# %%
X_train_cln
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.67747846,
#         -0.12727176, -1.0837529 ],
#        [ 1.        ,  0.        ,  0.        , ..., -0.12578182,
#         -0.57356813, -0.91748761],
#        [ 0.        ,  0.        ,  0.        , ...,  0.72545087,
#          0.50995715, -0.52927086],
#        ...,
#        [ 1.        ,  0.        ,  0.        , ...,  0.93204432,
#          0.93263996,  1.25088884],
#        [ 0.        ,  0.        ,  1.        , ...,  0.70572242,
#          0.71387715,  1.107998  ],
#        [ 0.        ,  0.        ,  0.        , ..., -0.52934249,
#          0.32273532,  0.22733139]])

# %%
X_train_cln.shape, X_test_cln.shape
# Out:
# ((4238010, 30), (470890, 30))

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_cln, y_train_cln)

# %%
# Making predictions using the testing data.
predictions = rf_model.predict(X_test_cln)

# %%
# Calculating the confusion matrix.
cm = confusion_matrix(y_test_cln, predictions)

# %%
# Create a DataFrame from the confusion matrix.
# Generate confusion_matrix
cm_arr = confusion_matrix(y_test_cln, predictions)

mult_ix = pd.MultiIndex.from_tuples([
    ('actual','cancelled'),
    ('actual','not cancelled')
])

mult_cols = pd.MultiIndex.from_tuples([
    ('predicted','cancelled'),
    ('predicted','not cancelled')
])

cm_df = pd.DataFrame(
    data=cm_arr,
    index=mult_ix,
    columns=mult_cols
)

cm_df
# Out:
#                      predicted
#                      cancelled not cancelled
# actual cancelled        467233           261
#        not cancelled      2616           780

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test_cln, predictions)

# %%
import dataframe_image as dfi

# %%
dfi.export(cm_df,os.path.join('.','images','mlm_t05_random_forest_r_confusion_matrix.png'))
# Out:
# [0911/202818.236206:INFO:headless_shell.cc(660)] Written to file /var/folders/2r/t55htrbs3ynckzlh1s23dyqr0000gn/T/tmpt06tfjrz/temp.png.

# %%
# Displaying results
print(f"Accuracy Score : {acc_score}\n\n")
print("Classification Report\n")
print(classification_report(y_test, predictions))
# Out:
# Accuracy Score : 0.9938902928497101
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00    467494
#         True       0.75      0.23      0.35      3396
#
#     accuracy                           0.99    470890
#    macro avg       0.87      0.61      0.67    470890
# weighted avg       0.99      0.99      0.99    470890
