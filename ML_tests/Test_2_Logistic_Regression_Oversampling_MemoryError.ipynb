# %% [markdown]
# # Retrieve Data from Database

# %% [markdown]
# In order to connect to the database, first, make sure:
# 1. …you have a local (running) database with the `hostname`, `database` name, `username`, and `port` number as specified in `/resources/config/gadb_pg_config.py`.
# 2. …the `airports` and `flights_and_weather` tables have data.
#
# If the `airports` and `flights_and_weather` tables do not have data, you must first run `/download_and_prepare_datasets/02_prepare_and_store_data.ipynb` to populate the database.

# %%
import os
import time

# %%
os.chdir(os.path.join('..','resources'))

# %% [markdown]
# ## Connect to Database

# %%
# Database configuration details
from config import gadb_pg_config as cfg

# To connect to SQL database
import sqlalchemy as db
# from sqlalchemy import create_engine, MetaData, Table, text, types

# To enter passwords without exposing them
from getpass import getpass

# %% [markdown]
# Most of the database information is already in `cfg` (above). However, you will have to enter your password below.

# %%
password = getpass('Enter database password')
# Out:
# Enter database password········

# %%
start_time = time.time()

# %%
db_string = f"postgresql+psycopg2://{cfg.username}:{password}@{cfg.hostname}:{cfg.port}/{cfg.database}"

# %%
engine = db.create_engine(
    future=True,
#     echo=True,
    url=db_string
)

# %% [markdown]
# ## Access Database Tables and Create Table Aliases

# %%
db_meta = db.MetaData()

# %%
# Access the `airports` and `flights_and_weather` tables and assign them to variables
airports_table = db.Table('airports', db_meta, autoload_with=engine)
faw_table = db.Table('flights_and_weather', db_meta, autoload_with=engine)
faw = faw_table.alias('faw')
orig = airports_table.alias('orig')
dest = airports_table.alias('dest')

# %% [markdown]
# ## Extract Full, Joined Dataset to Pandas Dataframe

# %%
from io import StringIO
import pandas as pd

# %%
# Function to extract from database query to Pandas dataframe
# Adapted from <https://towardsdatascience.com/optimizing-pandas-read-sql-for-postgres-f31cd7f707ab>
def read_sql_inmem(query, db_engine, **kwargs):
    copy_sql = "COPY ({query}) TO STDOUT WITH CSV {head}".format(
       query=query, head="HEADER"
    )
    conn = db_engine.raw_connection()
    cur = conn.cursor()
    store = StringIO()
    cur.copy_expert(copy_sql, store)
    store.seek(0)
    df = pd.read_csv(store, **kwargs)
    return df

# %%
# The query composed as an SQLAlchemy table object
get_all = (
    db.select([
        faw,
        orig.c.lat_decimal.label('origin_lat'),
        orig.c.lon_decimal.label('origin_lon'),
        dest.c.lat_decimal.label('destination_lat'),
        dest.c.lon_decimal.label('destination_lon')
    ])
    .select_from(
        faw
        .join(orig, orig.c.iata_code == faw.c.origin_airport, isouter=True)
        .join(dest, dest.c.iata_code == faw.c.destination_airport, isouter=True)
    )
    .order_by(faw.c.id)
)

# %%
def print_shape(df):
    df_rows, df_cols = df.shape
    print(f"{df_rows:,} rows × {df_cols:,} columns")

# %%
def df_details(df):
    return pd.concat(
        [
            df.dtypes,
            df.isna().sum(),
            pd.Series(
                data=[df[col].dropna().is_unique for col in df.columns],
                index=df.columns
            )
        ],
        axis=1,
        keys=['data_type','null_count','unique']
    )

# %%
# Run the query, and save the result to a dataframe
combined_df = read_sql_inmem(
    query=get_all,
#     query=get_all.limit(10).compile(engine, compile_kwargs={"literal_binds": True}),
    db_engine=engine,
    index_col='id',
    converters={'cancelled':(lambda x: True if x == 't' else False)}
)
# .sort_index(kind='mergesort')

print_shape(combined_df)
# Out:
# 5,468,069 rows × 35 columns

# %%
# "Full-width display" function to display all columns of a dataframe
def fw_disp(df):
    with pd.option_context('display.max_columns',None):
        display(df)

# %%
fw_disp(combined_df.head())
# Out:
#    carrier_code  flight_number origin_airport destination_airport flight_date  \
# id
# 0            AS            121            SEA                 ANC  2019-05-01
# 1            F9            402            LAX                 DEN  2019-05-01
# 2            F9            662            SFO                 DEN  2019-05-01
# 3            F9            790            PDX                 DEN  2019-05-01
# 4            AS            108            ANC                 SEA  2019-05-01
#
#     scheduled_elapsed_time tail_number  departure_delay  arrival_delay  \
# id
# 0                      215      N615AS               -8            -16
# 1                      147      N701FR               17             -4
# 2                      158      N346FR               44             27
# 3                      156      N332FR               24             10
# 4                      210      N548AS               -9            -31
#
#     delay_carrier  delay_weather  delay_national_aviation_system  \
# id
# 0               0              0                               0
# 1               0              0                               0
# 2               0              0                               0
# 3               0              0                               0
# 4               0              0                               0
#
#     delay_security  delay_late_aircarft_arrival  cancelled  \
# id
# 0                0                            0      False
# 1                0                            0      False
# 2                0                           27      False
# 3                0                            0      False
# 4                0                            0      False
#
#    scheduled_departure_dt scheduled_arrival_dt  actual_departure_dt  \
# id
# 0     2019-05-01 00:40:00  2019-05-01 03:15:00  2019-05-01 00:32:00
# 1     2019-05-01 00:59:00  2019-05-01 04:26:00  2019-05-01 01:16:00
# 2     2019-05-01 00:50:00  2019-05-01 04:28:00  2019-05-01 01:34:00
# 3     2019-05-01 00:55:00  2019-05-01 04:31:00  2019-05-01 01:19:00
# 4     2019-05-01 00:10:00  2019-05-01 04:40:00  2019-05-01 00:01:00
#
#       actual_arrival_dt     station_x  hourlydrybulbtemperature_x  \
# id
# 0   2019-05-01 02:59:00  7.279302e+10                        49.0
# 1   2019-05-01 04:22:00  7.229502e+10                        58.0
# 2   2019-05-01 04:55:00  7.249402e+10                        51.0
# 3   2019-05-01 04:41:00  7.269802e+10                        48.0
# 4   2019-05-01 04:09:00  7.027253e+10                        43.0
#
#     hourlyprecipitation_x  hourlystationpressure_x  hourlyvisibility_x  \
# id
# 0                     0.0                    29.59                10.0
# 1                     0.0                    29.65                10.0
# 2                     0.0                    29.98                10.0
# 3                     0.0                    29.98                10.0
# 4                     0.0                    30.18                10.0
#
#     hourlywindspeed_x     station_y  hourlydrybulbtemperature_y  \
# id
# 0                 8.0  7.027253e+10                        42.0
# 1                 3.0  7.256500e+10                        34.0
# 2                 6.0  7.256500e+10                        34.0
# 3                 0.0  7.256500e+10                        34.0
# 4                 5.0  7.279302e+10                        44.0
#
#     hourlyprecipitation_y  hourlystationpressure_y  hourlyvisibility_y  \
# id
# 0                     0.0                    30.16                10.0
# 1                     0.0                    24.43                 4.0
# 2                     0.0                    24.43                 4.0
# 3                     0.0                    24.43                 4.0
# 4                     0.0                    29.58                10.0
#
#     hourlywindspeed_y  origin_lat  origin_lon  destination_lat  \
# id
# 0                 3.0      47.449    -122.309           61.174
# 1                 0.0      33.942    -118.408           39.858
# 2                 0.0      37.619    -122.375           39.858
# 3                 0.0      45.589    -122.597           39.858
# 4                 7.0      61.174    -149.996           47.449
#
#     destination_lon
# id
# 0          -149.996
# 1          -104.667
# 2          -104.667
# 3          -104.667
# 4          -122.309

# %%
df_details(combined_df)
# Out:
#                                data_type  null_count  unique
# carrier_code                      object           0   False
# flight_number                      int64           0   False
# origin_airport                    object           0   False
# destination_airport               object           0   False
# flight_date                       object           0   False
# scheduled_elapsed_time             int64           0   False
# tail_number                       object        6973   False
# departure_delay                    int64           0   False
# arrival_delay                      int64           0   False
# delay_carrier                      int64           0   False
# delay_weather                      int64           0   False
# delay_national_aviation_system     int64           0   False
# delay_security                     int64           0   False
# delay_late_aircarft_arrival        int64           0   False
# cancelled                           bool           0   False
# scheduled_departure_dt            object           0   False
# scheduled_arrival_dt              object           0   False
# actual_departure_dt               object       40065   False
# actual_arrival_dt                 object       43808   False
# station_x                        float64        2073   False
# hourlydrybulbtemperature_x       float64        2073   False
# hourlyprecipitation_x            float64        9881   False
# hourlystationpressure_x          float64        2073   False
# hourlyvisibility_x               float64        2073   False
# hourlywindspeed_x                float64        2073   False
# station_y                        float64        2078   False
# hourlydrybulbtemperature_y       float64        2078   False
# hourlyprecipitation_y            float64        9896   False
# hourlystationpressure_y          float64        2078   False
# hourlyvisibility_y               float64        2078   False
# hourlywindspeed_y                float64        2078   False
# origin_lat                       float64      382438   False
# origin_lon                       float64      382438   False
# destination_lat                  float64      382775   False
# destination_lon                  float64      382775   False

# %%
print(f'Elapsed time: {(time.time() - start_time):,.3f} seconds.')
# Out:
# Elapsed time: 154.969 seconds.

# %% [markdown]
# ## Prepare Data for Machine Learning

# %% [markdown]
# ### Ensure Proper Column Structure

# %%
# Select columns to drop
drop_cols = [
    'flight_number',
    'origin_airport',
    'destination_airport',
#     'tail_number',
    'departure_delay',
    'arrival_delay',
    'delay_carrier',
    'delay_weather',
    'delay_national_aviation_system',
    'delay_security',
    'delay_late_aircarft_arrival',
    'actual_departure_dt',
    'actual_arrival_dt'
]

# %% [markdown]
# Drop the `…_airport` columns because their coordinates will serve in their stead.
#
# Drop the `…delay…` columns because they could not be known prior to their occurrence (and because we're trying to predict cancellations based on weather, specifically).
#
# Drop the `actual_…_dt` columns because their absence *defines* a cancellation (which is what we're trying to predict).
#
# Leaving `tail_number` in because the model may be able to make inferences based on a particular plane's earlier or later schedule.

# %%
df = combined_df.drop(columns=drop_cols)

# %%
fw_disp(df.head())
# Out:
#    carrier_code flight_date  scheduled_elapsed_time tail_number  cancelled  \
# id
# 0            AS  2019-05-01                     215      N615AS      False
# 1            F9  2019-05-01                     147      N701FR      False
# 2            F9  2019-05-01                     158      N346FR      False
# 3            F9  2019-05-01                     156      N332FR      False
# 4            AS  2019-05-01                     210      N548AS      False
#
#    scheduled_departure_dt scheduled_arrival_dt     station_x  \
# id
# 0     2019-05-01 00:40:00  2019-05-01 03:15:00  7.279302e+10
# 1     2019-05-01 00:59:00  2019-05-01 04:26:00  7.229502e+10
# 2     2019-05-01 00:50:00  2019-05-01 04:28:00  7.249402e+10
# 3     2019-05-01 00:55:00  2019-05-01 04:31:00  7.269802e+10
# 4     2019-05-01 00:10:00  2019-05-01 04:40:00  7.027253e+10
#
#     hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 0                         49.0                    0.0
# 1                         58.0                    0.0
# 2                         51.0                    0.0
# 3                         48.0                    0.0
# 4                         43.0                    0.0
#
#     hourlystationpressure_x  hourlyvisibility_x  hourlywindspeed_x  \
# id
# 0                     29.59                10.0                8.0
# 1                     29.65                10.0                3.0
# 2                     29.98                10.0                6.0
# 3                     29.98                10.0                0.0
# 4                     30.18                10.0                5.0
#
#        station_y  hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 0   7.027253e+10                        42.0                    0.0
# 1   7.256500e+10                        34.0                    0.0
# 2   7.256500e+10                        34.0                    0.0
# 3   7.256500e+10                        34.0                    0.0
# 4   7.279302e+10                        44.0                    0.0
#
#     hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 0                     30.16                10.0                3.0
# 1                     24.43                 4.0                0.0
# 2                     24.43                 4.0                0.0
# 3                     24.43                 4.0                0.0
# 4                     29.58                10.0                7.0
#
#     origin_lat  origin_lon  destination_lat  destination_lon
# id
# 0       47.449    -122.309           61.174         -149.996
# 1       33.942    -118.408           39.858         -104.667
# 2       37.619    -122.375           39.858         -104.667
# 3       45.589    -122.597           39.858         -104.667
# 4       61.174    -149.996           47.449         -122.309

# %%
# Date and time columns to be converted
dt_cols = [
    'flight_date',
    'scheduled_departure_dt',
    'scheduled_arrival_dt'
]

# %%
df[dt_cols].head()
# Out:
#    flight_date scheduled_departure_dt scheduled_arrival_dt
# id
# 0   2019-05-01    2019-05-01 00:40:00  2019-05-01 03:15:00
# 1   2019-05-01    2019-05-01 00:59:00  2019-05-01 04:26:00
# 2   2019-05-01    2019-05-01 00:50:00  2019-05-01 04:28:00
# 3   2019-05-01    2019-05-01 00:55:00  2019-05-01 04:31:00
# 4   2019-05-01    2019-05-01 00:10:00  2019-05-01 04:40:00

# %%
from datetime import datetime
import numpy as np

# %%
# Convert the date and time columns to Unix timestamps (integers)
for col in dt_cols:
    df[col] = pd.to_datetime(df[col]).view(np.int64)

# %%
df[dt_cols].dtypes
# Out:
# flight_date               int64
# scheduled_departure_dt    int64
# scheduled_arrival_dt      int64
# dtype: object

# %%
fw_disp(df.head())
# Out:
#    carrier_code          flight_date  scheduled_elapsed_time tail_number  \
# id
# 0            AS  1556668800000000000                     215      N615AS
# 1            F9  1556668800000000000                     147      N701FR
# 2            F9  1556668800000000000                     158      N346FR
# 3            F9  1556668800000000000                     156      N332FR
# 4            AS  1556668800000000000                     210      N548AS
#
#     cancelled  scheduled_departure_dt  scheduled_arrival_dt     station_x  \
# id
# 0       False     1556671200000000000   1556680500000000000  7.279302e+10
# 1       False     1556672340000000000   1556684760000000000  7.229502e+10
# 2       False     1556671800000000000   1556684880000000000  7.249402e+10
# 3       False     1556672100000000000   1556685060000000000  7.269802e+10
# 4       False     1556669400000000000   1556685600000000000  7.027253e+10
#
#     hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 0                         49.0                    0.0
# 1                         58.0                    0.0
# 2                         51.0                    0.0
# 3                         48.0                    0.0
# 4                         43.0                    0.0
#
#     hourlystationpressure_x  hourlyvisibility_x  hourlywindspeed_x  \
# id
# 0                     29.59                10.0                8.0
# 1                     29.65                10.0                3.0
# 2                     29.98                10.0                6.0
# 3                     29.98                10.0                0.0
# 4                     30.18                10.0                5.0
#
#        station_y  hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 0   7.027253e+10                        42.0                    0.0
# 1   7.256500e+10                        34.0                    0.0
# 2   7.256500e+10                        34.0                    0.0
# 3   7.256500e+10                        34.0                    0.0
# 4   7.279302e+10                        44.0                    0.0
#
#     hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 0                     30.16                10.0                3.0
# 1                     24.43                 4.0                0.0
# 2                     24.43                 4.0                0.0
# 3                     24.43                 4.0                0.0
# 4                     29.58                10.0                7.0
#
#     origin_lat  origin_lon  destination_lat  destination_lon
# id
# 0       47.449    -122.309           61.174         -149.996
# 1       33.942    -118.408           39.858         -104.667
# 2       37.619    -122.375           39.858         -104.667
# 3       45.589    -122.597           39.858         -104.667
# 4       61.174    -149.996           47.449         -122.309

# %%
combined_df[['carrier_code','tail_number']].nunique(dropna=True)
# Out:
# carrier_code      10
# tail_number     6111
# dtype: int64

# %%
# Drop rows with `NULL` values
df.dropna(how='any',inplace=True)

print_shape(df)
# Out:
# 4,703,316 rows × 23 columns

# %%
# Verify that no `NULL` values remain
df.isna().sum()
# Out:
# carrier_code                  0
# flight_date                   0
# scheduled_elapsed_time        0
# tail_number                   0
# cancelled                     0
# scheduled_departure_dt        0
# scheduled_arrival_dt          0
# station_x                     0
# hourlydrybulbtemperature_x    0
# hourlyprecipitation_x         0
# hourlystationpressure_x       0
# hourlyvisibility_x            0
# hourlywindspeed_x             0
# station_y                     0
# hourlydrybulbtemperature_y    0
# hourlyprecipitation_y         0
# hourlystationpressure_y       0
# hourlyvisibility_y            0
# hourlywindspeed_y             0
# origin_lat                    0
# origin_lon                    0
# destination_lat               0
# destination_lon               0
# dtype: int64

# %% [markdown]
# ### Oversample Cancelled Flights

# %%
# Identify target sample size (i.e., the number of non-cancelled flights in the dataset)
nc_flights = df.cancelled.value_counts()[False]
nc_flights
# Out:
# 4674943

# %%
# Create oversampled dataframe with rows shuffled in random order
df_oversamp = pd.concat([
    df.loc[~df.cancelled],
    df.loc[df.cancelled].sample(nc_flights,replace=True)
]).sample(frac=1)

# %%
# Verify that df_oversamp has the twice the numer of rows as the non-cancelled flights in df
df_oversamp.index.size == 2 * nc_flights
# Out:
# True

# %%
print_shape(df_oversamp)
# Out:
# 9,349,886 rows × 23 columns

# %% [markdown]
# ### Separate the features (X) from the target (y)

# %%
y = df_oversamp.cancelled
X = df_oversamp.drop(columns="cancelled")

# %%
fw_disp(X.head())
# Out:
#         carrier_code          flight_date  scheduled_elapsed_time tail_number  \
# id
# 2135401           AA  1564704000000000000                     117      N521UW
# 1513371           AA  1562371200000000000                     237      N194UW
# 3710902           WN  1570665600000000000                     170      N234WN
# 1456240           WN  1562198400000000000                      85      N929WN
# 839013            WN  1559865600000000000                     115      N8640D
#
#          scheduled_departure_dt  scheduled_arrival_dt     station_x  \
# id
# 2135401     1564734120000000000   1564741140000000000  7.253709e+10
# 1513371     1562454420000000000   1562479440000000000  7.227802e+10
# 3710902     1570740300000000000   1570754100000000000  7.225801e+10
# 1456240     1562224800000000000   1562229900000000000  7.223101e+10
# 839013      1559912400000000000   1559915700000000000  7.256500e+10
#
#          hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 2135401                        69.0                   0.00
# 1513371                        95.0                   0.00
# 3710902                        66.0                   0.32
# 1456240                        82.0                   0.00
# 839013                         74.0                   0.00
#
#          hourlystationpressure_x  hourlyvisibility_x  hourlywindspeed_x  \
# id
# 2135401                    29.47                10.0                6.0
# 1513371                    28.66                10.0                7.0
# 3710902                    29.33                 6.0               21.0
# 1456240                    30.01                 8.0                3.0
# 839013                     24.48                 8.0                9.0
#
#             station_y  hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 2135401  7.231401e+10                        77.0                    0.0
# 1513371  7.231401e+10                        75.0                    0.0
# 3710902  7.240609e+10                        61.0                    0.0
# 1456240  7.225801e+10                        84.0                    0.0
# 839013   7.238602e+10                        96.0                    0.0
#
#          hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 2135401                    29.30                 7.0                0.0
# 1513371                    29.14                10.0                5.0
# 3710902                    29.98                10.0                6.0
# 1456240                    29.42                10.0               11.0
# 839013                     27.44                10.0               15.0
#
#          origin_lat  origin_lon  destination_lat  destination_lon
# id
# 2135401      42.212     -83.353           35.214          -80.943
# 1513371      33.434    -112.008           35.214          -80.943
# 3710902      32.847     -96.852           39.175          -76.668
# 1456240      29.993     -90.258           32.847          -96.852
# 839013       39.858    -104.667           36.080         -115.152

# %% [markdown]
# ### Create training and testing subsets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state=1,
    test_size=0.1
)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8414897, 22), (934989, 22), (8414897,), (934989,))

# %% [markdown]
# ### Encode Target, and Encode and Scale Features

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler

# %%
le = LabelEncoder()

# %%
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.fit_transform(y_test)

# %%
le.classes_
# Out:
# array([False,  True])

# %%
y_train_enc
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
y_test_enc
# Out:
# array([1, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train.columns
# Out:
# Index(['carrier_code', 'flight_date', 'scheduled_elapsed_time', 'tail_number',
#        'scheduled_departure_dt', 'scheduled_arrival_dt', 'station_x',
#        'hourlydrybulbtemperature_x', 'hourlyprecipitation_x',
#        'hourlystationpressure_x', 'hourlyvisibility_x', 'hourlywindspeed_x',
#        'station_y', 'hourlydrybulbtemperature_y', 'hourlyprecipitation_y',
#        'hourlystationpressure_y', 'hourlyvisibility_y', 'hourlywindspeed_y',
#        'origin_lat', 'origin_lon', 'destination_lat', 'destination_lon'],
#       dtype='object')

# %%
fw_disp(X_train.head())
# Out:
#         carrier_code          flight_date  scheduled_elapsed_time tail_number  \
# id
# 4831673           WN  1575072000000000000                     125      N400WN
# 4743207           WN  1574726400000000000                      75      N220WN
# 2348103           AA  1565481600000000000                      58      N595NN
# 67425             WN  1556841600000000000                      85      N786SW
# 4836652           UA  1575158400000000000                     245      N160SY
#
#          scheduled_departure_dt  scheduled_arrival_dt     station_x  \
# id
# 4831673     1575150300000000000   1575157800000000000  7.225801e+10
# 4743207     1574776500000000000   1574781000000000000  7.225801e+10
# 2348103     1565522400000000000   1565525880000000000  7.231401e+10
# 67425       1556919600000000000   1556924700000000000  7.238602e+10
# 4836652     1575186600000000000   1575194100000000000  7.235301e+10
#
#          hourlydrybulbtemperature_x  hourlyprecipitation_x  \
# id
# 4831673                        60.0                    0.0
# 4743207                        72.0                    0.0
# 2348103                        84.0                    0.0
# 67425                          77.0                    0.0
# 4836652                        34.0                    0.0
#
#          hourlystationpressure_x  hourlyvisibility_x  hourlywindspeed_x  \
# id
# 4831673                    29.36                10.0               14.0
# 4743207                    28.99                 9.0                8.0
# 2348103                    29.25                 9.0                3.0
# 67425                      27.56                10.0                0.0
# 4836652                    28.67                10.0               20.0
#
#             station_y  hourlydrybulbtemperature_y  hourlyprecipitation_y  \
# id
# 4831673  7.253401e+10                        41.0                   0.02
# 4743207  7.236302e+10                        52.0                   0.00
# 2348103  7.230201e+10                        86.0                   0.00
# 67425    7.249302e+10                        53.0                   0.00
# 4836652  7.249402e+10                        56.0                   0.00
#
#          hourlystationpressure_y  hourlyvisibility_y  hourlywindspeed_y  \
# id
# 4831673                    28.75                 9.0                7.0
# 4743207                    25.85                10.0               38.0
# 2348103                    29.96                10.0               13.0
# 67425                      29.86                10.0                8.0
# 4836652                    29.87                 8.0               17.0
#
#          origin_lat  origin_lon  destination_lat  destination_lon
# id
# 4831673      32.847     -96.852           41.786          -87.752
# 4743207      32.847     -96.852           35.219         -101.706
# 2348103      35.214     -80.943           34.271          -77.903
# 67425        36.080    -115.152           37.721         -122.221
# 4836652      35.393     -97.601           37.619         -122.375

# %%
# Identify columns for one-hot encoding, min-max scaling, and standard scaling

# One-hot columns
oh_cols = ['carrier_code','tail_number']

# Min-max columns. These features are expected
# to have a somewhat even distribution
mm_cols = [
    'flight_date',
    'scheduled_departure_dt',
    'scheduled_arrival_dt',
    'origin_lat',
    'origin_lon',
    'destination_lat',
    'destination_lon'
]

# Standard-scale columns. These features are expected
# to have distributions with notable central tendencies
ss_cols = [
    'scheduled_elapsed_time',
    'station_x',
    'hourlydrybulbtemperature_x',
    'hourlyprecipitation_x',
    'hourlystationpressure_x',
    'hourlyvisibility_x',
    'hourlywindspeed_x',
    'station_y',
    'hourlydrybulbtemperature_y',
    'hourlyprecipitation_y',
    'hourlystationpressure_y',
    'hourlyvisibility_y',
    'hourlywindspeed_y'
]

# %%
col_xf = ColumnTransformer([
    (
        'ohe',
        OneHotEncoder(
            sparse=False,
            dtype=int,
            handle_unknown='ignore'
        ),
        oh_cols
    ),
    (
        'mm',
        MinMaxScaler(),
        mm_cols
    ),
    (
        'ss',
        StandardScaler(),
        ss_cols
    )
], remainder='passthrough')

# %%
# Free up memory
for _var in [
    'df_oversamp',
    'nc_flights',
    'dt_cols',
    'df',
    'drop_cols',
    'combined_df'
]:
    if _var in locals() or _var in globals():
        exec(f'del {_var}')

# %%
X_train_xf = col_xf.fit_transform(X_train)
X_test_xf = col_xf.fit_transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17360\3652097537.py in <module>
# ----> 1 X_train_xf = col_xf.fit_transform(X_train)
#       2 X_test_xf = col_xf.fit_transform(X_test)
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     673         self._validate_remainder(X)
#     674
# --> 675         result = self._fit_transform(X, y, _fit_transform_one)
#     676
#     677         if not result:
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\compose\_column_transformer.py in _fit_transform(self, X, y, func, fitted, column_as_strings)
#     613                     message=self._log_message(name, idx, len(transformers)),
#     614                 )
# --> 615                 for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     616             )
#     617         except ValueError as e:
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~\.conda\envs\mlenv\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     486         """
#     487         self._validate_keywords()
# --> 488         return super().fit_transform(X, y)
#     489
#     490     def transform(self, X):
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\.conda\envs\mlenv\lib\site-packages\sklearn\preprocessing\_encoders.py in transform(self, X)
#     555         )
#     556         if not self.sparse:
# --> 557             return out.toarray()
#     558         else:
#     559             return out
#
# ~\.conda\envs\mlenv\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1037         if out is None and order is None:
#    1038             order = self._swap('cf')[0]
# -> 1039         out = self._process_toarray_args(order, out)
#    1040         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1041             raise ValueError('Output array must be C or F contiguous')
#
# ~\.conda\envs\mlenv\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1200             return out
#    1201         else:
# -> 1202             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1203
#    1204
#
# MemoryError: Unable to allocate 192. GiB for an array with shape (8414897, 6118) and data type int32
